# %%
import numpy as np
import statistics

# %% [markdown]
# # Exercício 1 -

# %% [markdown]
# 1) Digitadores são treinados em uma empresa em duas turmas distintas. Na primeira (TURMA J) utiliza-se um método japonês, na segunda (TURMA A) utiliza-se um método alemão. Deseja-se comparar os dois métodos (hipótese nula de igualdade de médias e hipótese alternativa composta) usando nível de significância de 1%. Foram escolhidas duas amostras aleatoriamente (14 digitadores de J e 13 digitadores de A) e mediu-se o tempo gasto na realização de uma tarefa para cada aluno, tendo média 11,57 e variância 4,1 (em J) e média 15,38 e variância 4,3 (em A).

# %% [markdown]
# Sc = ((n1-1)*Sj + (n2-1)Sa)/(n1-1)+(n2-1) = 20.06
#
# D = 11.57-15.38 = -3.81
#
# t=D/sqrt(sc*((1/n1)+(1/n2))) = -2.20
#
# graus = 14 + 13 - 2 = 25
#
# Não está na região crítica entre tc > 2.79 ou tc < -2.79, portanto, não difere

# %%
print(((14-1)*4.1 + (13-1)*4.3)/(14-1)+(13-1))

print(-3.81/np.sqrt(20.06*((1/14)+(1/13))))
# Out:
# 20.06923076923077
# -2.2085809570404993

# %% [markdown]
# # Exercício 2 -

# %% [markdown]
# 2) Se tivéssemos o mesmo problema do Exercício 1, mas com média 11,57 e variância 4,26 (em J) e média 11,23 e variância 1,19 (em A), qual seria a conclusão usando nível de significância de 10%?

# %% [markdown]
# Sc = ((n1-1)*Sj + (n2-1)Sa)/(n1-1)+(n2-1) = 17.35
#
# D = 11.57-11.23 = 0.34
#
# t=D/sqrt(sc*((1/n1)+(1/n2))) = 0.21
#
# graus = 20
#
# Não está na região crítica entre tc > 1.72 ou tc < -1.72, portanto, não difere

# %%
j = (4.26/14)**2/13

k = ((1.19/13)**2/12)

l = ((4.26/14) + (1.19/13))**2

print( l / (j+k))

print(((14-1)*4.26 + (13-1)*1.19)/(14-1)+(13-1))

print(0.34/np.sqrt(17.35*((1/14)+(1/13))))
# Out:
# 20.03394320212707
# 17.35846153846154
# 0.21192538919119702

# %% [markdown]
# # Exercício 3 -

# %% [markdown]
# 3) Temos duas porções idênticas de cascalho coletadas a uma dada profundidade; uma das porções foi analisada pelo Laboratório A e, a outra, pelo Laboratório B, ambos usando o mesmo procedimento. A amostra consiste em 25 pares dessas porções, em que cada par é coletado a uma profundidade diferente. A característica a ser medida é o conteúdo de oxigênio no material coletado. Seja ∆_𝑖=𝑋_𝑖−𝑌_𝑖 a diferença entre os valores obtidos pelos laboratórios A e B para o i-ésimo material coletado (𝑖=1,2,3,…,25). Então, para a V.A. ∆=𝑋−𝑌, tem-se que o valor de média amostral é 0,27 e desvio padrão amostral 0,20. Podemos afirmar que, em média, as medições feitas no Lab. A tendem a resultar maiores do que as feitas no Lab. B para 𝛼=0,05 ?

# %% [markdown]
# graus = 25-1 = 24
#
# tc > 1.71 ou tc < -1.71
#
# t = 0.27 / 0.20 / sqrt(25) = 6.75, rejeita-se a igualdade das médias dos laboratórios e o Lab A tende a atribuir valores maiores que o B

# %%
 print(0.27*5/0.20)
# Out:
# 6.75

# %% [markdown]
# # Exercício 4 -

# %% [markdown]
# 4) Uma fábrica produz diariamente uma grande quantidade de peças de um certo tipo. Em um determinado dia foi selecionada da linha de produção uma A.A. de 50 peças, das quais 4 estavam fora das especificações. Após uma pane da máquina no dia seguinte, 50 peças foram selecionadas e, dessas, 6 peças estavam fora das especificações. Qual seria a conclusão ao nível de significância de 5% sobre a proporção de peças não conformes produzidas no segundo dia?

# %% [markdown]
# n = m = 50,
#
# X = 4 e Y = 6
#
# p1= 4/50=0.08, p2 = 6/50=0.12 e p = 10/100 = 0.1
#
# `Zobs = (p1-p2)/p*(1-p)*((1/50)+(1/50))=-0.67`
#
# Zc = -1.64
#
# como Zobs > Zc, temos que não há evidencias para rejeitar a tese, ou seja, não houve pane na máquina em 5% de significância.

# %% [markdown]
# # Exercício 5 -

# %% [markdown]
# 5) A comparação entre concretos fabricados com cimentos de duas marcas diferentes possui, em uma dada amostra, as seguintes estatísticas: Marca 1 (n=12 e variância=0,1561) e Marca 2 (m=10 e variância=0,1690). Supondo que ambas V.A.s são normais, qual a conclusão quando a hipótese nula de variâncias iguais é testada contra a hipótese alternativa de variâncias diferentes, ao nível de significância de 5%?

# %% [markdown]
# 11(9)GL,
#
# Fobs = 0.1561/0.1690 = 0.9236
#
# F1 = 0.28 e F2 = 3.91, ou seja, F < 0.28 ou F > 3.91 é a região crítica, e como 0.9236 não pertence à região crítica, então não rejeitamos a hipótese.

# %%
print(0.1561/0.1690)
# Out:
# 0.9236686390532544
