# %%
import numpy as np
from scipy.stats import norm

# %% [markdown]
# # Exercício 1

# %% [markdown]
# 1) O consumo de gêneros alimentícios por família em uma certa região tem distribuição normal com desvio padrão = 100 unidades e média desconhecida. Se desejarmos estimar a média com erro máximo de ε=30 e com uma confiança de 95%, quantas famílias devemos consultar?

# %% [markdown]
# Seja a forma dada, teremos em Z_47.5:
#
# `n = (Z*dp/E)**2 = 42.68`

# %%
E = 30
Z = 1.96
dp = 100

n = (Z*dp/E)**2 
print(n)
# Out:
# 42.684444444444445

# %% [markdown]
# # Exercício 2 -

# %% [markdown]
# 2) Clique em verdadeiro ou falso nas informações abaixo:

# %% [markdown]
# a) São técnicas de amostragem probabilísticas: amostragem aleatória simples, amostragem estratificada, amostragem por cotas e amostragem sistemática.

# %% [markdown]
# **Verdadeiro**, visto que as técnicas de amostragem probabilística deve satisfazer os seguintes pressupostos:
#
# (1) Todos os elementos da minha população apresentam uma probabilidade maior que zero para ser selecionados na amostra.
#
# (2) Conhecer precisamente a probabilidade para cada elemento, também chamado de probabilidade de inclusão.

# %% [markdown]
# b) Técnicas de amostragem não-probabilísticas são aquelas cuja generalização dos resultados das pesquisas para a população não são permitidas, tendo em vista que há uma escolha deliberada dos elementos da mesma.

# %% [markdown]
# **Falso**, porque não há uma escolha deliberada dos elementos da amostragem não probabilística. "Nestas técnicas alternativas, é comum selecionar elementos para a amostra com base em premissas em relação à população de interesse, conhecido como critério de seleção. Por exemplo, selecionar uma amostra buscando por indivíduos na rua, onde metade precisam ser homens e a outra metade, mulheres (coincidindo com a distribuição assumida na população), isso representa um critério de amostra não probabilística". Tanto que nessas amostras, não há estimativas de erros.

# %% [markdown]
# c) Dada uma variável aleatória X com distribuição normal, com média 100 e desvio padrão 10. Se X ̅ for a média de uma amostra de 16 elementos retirados dessa população, então as distribuições de X e X ̅ serão iguais.

# %% [markdown]
# **Verdadeiro**, pois pelo teorema do Limite Central, temos que se a distribuição de X é normal, então qualquer X ̅ tem distribuição normal exata, para todo n imposto.

# %% [markdown]
# d) O desvio padrão da distribuição das médias amostrais diminui quando o tamanho da amostra n diminui, o que significa que, assim, a média da amostra aproxima-se da média da população.

# %% [markdown]
# **Falso**, pois o desvio padrão da distribuição das médias amostrais diminui quando o tamanho da amostra n aumenta. Ou seja, quanto mais tu adiciona elementos na tua amostra, o desvio padrão tem a tendência de ficar menor.

# %% [markdown]
# e) A Amostragem Estratificada é uma técnica de amostragem probabilística utilizada no caso de uma população heterogênea onde existem estratos e, assim, são selecionadas amostras aleatórias simples de cada estrato.

# %% [markdown]
# **Verdadeiro**, a Amostragem Estratificada é uma técnica de seleção de amostras por estrato, onde essas amostras aleatórias são selecionadas por meio de qualquer uma das técnicas de seleção de amostra.

# %% [markdown]
# f) O Teorema do Limite Central estabelece que, para X uma variável aleatória com média μ e variância σ^2, e (X_1,…,X_n) uma AAS de X, a distribuição amostral da média X ̅ aproxima-se, para n grande, de uma distribuição normal, com média μ e variância σ^2/n.

# %% [markdown]
# **Verdadeiro**, pois é a definição do Teorema do Limite Central.

# %% [markdown]
# # Exercício 3

# %% [markdown]
# 3) Uma variável aleatória X tem distribuição normal, com média 100 e variância 100.

# %% [markdown]
# a) Qual a 𝑃(90 < 𝑋 < 110)?

# %% [markdown]
# Para calcular a probabilidade, teremos:
#
# `P((90-100)/100, Z, (110-100)/100) = P(-0.1, Z, 0.1) =  P(Z <= 0.1) - P(Z <= -0.1) = 0.5398 - 0.4601 = 0.0796`

# %%
p = 0.5398-0.4601
print(p)
# Out:
# 0.07969999999999994

# %% [markdown]
# 3b) Se 𝑋 ̅ for a média de uma amostra de 16 elementos retirados dessa população, calcule 𝑃(90 <𝑋 ̅< 110).

# %% [markdown]
# Como X é uma variável aleatória em distribuição normal, temos que X e X ̅ possuem a mesma distribuição, portanto, pelo Teorema do Limite Central, temos que a média de X ̅ é 100 e sua variância é 100/16 = 6.25
#
# `P((90-100)/6.25, Z, (110-100)/6.25) = P(-1.6, Z, 1.6) = P(Z > 1.6)- P(Z > -1.6) = 0.9452 - 0.0548 = 0.8904`

# %%
p = 0.9452 - 0.0548
print(p)
# Out:
# 0.8904000000000001

# %% [markdown]
# 3c) Que tamanho deveria ter a amostra para que 𝑃(90 <𝑋 ̅< 110)=0,95 ?

# %% [markdown]
# Como X é uma variável aleatória em distribuição normal, temos que X e X ̅ possuem a mesma distribuição, portanto, pelo Teorema do Limite Central, temos que a média de X ̅ é 100 e sua variância é 100/n :
#
# `P(-10/100/n, Z, 10/100/n) = 0.95 => P(-2, Z, 2) = 0.9772 - 0.0227 = 0.954 => 5 = 100/n => n = 20 `

# %%
p = 0.9772 - 0.02275
print(p)
# Out:
# 0.9544499999999999
