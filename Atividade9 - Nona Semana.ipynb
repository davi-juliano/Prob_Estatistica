# %%
import numpy as np
import statistics

# %% [markdown]
# # Exercício 1 -

# %% [markdown]
# 1) Suponha que queiramos testar H_0: µ = 50 vs. H_1: µ>50, onde µ é a média de uma normal N(µ,900). Extraída uma amostra de n = 36 elementos da população, obtemos X ̅=52. Qual o p-valor do teste?

# %% [markdown]
# P(Z < 52-50/sqrt(900/36)) = P(Z < 0.4) = 0.1554

# %%
print((52-50)/(30/6))

print((52-50)/30)
# Out:
# 0.4
# 0.06666666666666667

# %% [markdown]
# # Exercício 2 -

# %% [markdown]
# 2) Digitadores de uma multinacional possuem um tempo X (em horas) de digitação associada a determinado relatório, com X seguindo a distribuição N(25; 100). Uma nova técnica de digitalização foi testada em 16 digitadores, os quais tiveram, como tempo médio, 20,5 horas. Usando o p-valor, você diria que a nova técnica é melhor que a anterior?

# %% [markdown]
# P(Z < 25-20.5/sqrt(100/16)) = P(Z < 1.8) = 0.03593

# %%
print((25-20.5)/np.sqrt(100/16))
# Out:
# 1.8

# %% [markdown]
# # Exercício 3 -

# %% [markdown]
# 3) Um fabricante de baterias automotivas afirma que a vida útil delas tem um desvio padrão de 0,7. Uma amostra foi retirada e o tempo anotado: 2,1; 3,1; 1,5; 3,4; 2,2. Ao nível de significância de 5%, a variância na vida útil das baterias é diferente do que é anunciado pela indústria?

# %% [markdown]
# a = 0.05
#
# variancia = 0.4899
#
# X barra = 2.46, n = 5, dpbarra = 0.776
#
# 0.05 = P(Z > xc - 2.46/ 0.7/ sqrt(5)) => 1.64 * 0.3130 + 2.46 = xc = 2.97332
#
# T = (0.776 - 0.7)/ 0.776/ sqrt(5) = 0.04379, variancia = 0.1917%, portanto não rejeita-se a tese

# %%
def Average(lst): 
    return sum(lst) / len(lst)

# %%
amostra = [2.1, 3.1, 1.5, 3.4, 2.2]

media = Average(amostra)

print(media)

print((0.776 - 0.7)/0.776/np.sqrt(5))

print(0.04379**2)

print(statistics.stdev(amostra))
# Out:
# 2.46
# 0.04379926966236705
# 0.0019175641000000003
# 0.776530746332687

# %% [markdown]
# # Exercício 4 -

# %% [markdown]
# 4) Uma empresa A afirma que 60% das vendas de determinado produto é de sua marca. Uma empresa concorrente B deseja contestar essa afirmação e decide usar uma amostra de 200 famílias para um teste. Destas, 104, confirmaram ter comprado da marca A. Considerando α = 5%, utilize o p-valor para testar a veracidade da afirmação da empresa A.

# %% [markdown]
# Z = (pchapeu - 0.6)/sqrt(0.6(1-0.6)/200) = (0.52 - 0.6)/sqrt(0.6*0.4/200) = -2.30
#
# Z de a = -1.64
#
# pchapeu = 104/200 = 0.52, portanto rejeita-se a afirmação

# %%
print(104/200)

print((0.52 - 0.6)/np.sqrt(0.6*0.4/200))
# Out:
# 0.52
# -2.309401076758502

# %% [markdown]
# # Exercício 5 -

# %% [markdown]
# 5) Uma montadora precisa testar o tempo de aceleração em 100 motos em função de um novo óleo. O engenheiro mecânico sabe que a média do tempo de aceleração para as motos sem o novo óleo é de 1,2 segundos. A média do tempo de resposta das 100 motos com o novo óleo é de 1,05 segundos, com um desvio padrão amostral de 0,5 segundo. Utilizando o p-valor em um teste de hipóteses bilateral, você acha que o novo óleo tem efeito no tempo de aceleração?

# %% [markdown]
# Z = Xbarra - Ybarra / dp /sqrt(1/100 + 1/100) = 1.2 - 1.05/0.5/ sqrt(1/50) = 2.12, ou seja, P(Z < 2.12) = 0.017 = 1.7%
#
# a=0.05 = 5%

# %%
print((1.2 - 1.05)/0.5/np.sqrt(1/50))
# Out:
# 2.1213203435596415
